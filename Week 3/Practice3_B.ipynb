# %%
import requests
link = "http://api.openweathermap.org/data/2.5/forecast"

lat = float(input("enter the latitude of the contry "))
lon = float(input("enter the longitudinal of the contry "))


additional_data = {
    "APPID" : "548cc7fc7bf7ebdd8e4d4022de5f7b7d",
    "lat" : lat,
    "lon" : lon
}

data = requests.get(link,params=additional_data).json()

print(data)
# Out:
# enter the latitude of the contry 35
# enter the longitudinal of the contry 139
# ...
